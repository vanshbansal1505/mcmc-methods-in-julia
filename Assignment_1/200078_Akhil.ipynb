# %%
using Distributions

# %%
using Plots

# %%
arr=[]
# Out:
# Any[]

# %%
for l in 1:100000
    i=0
    p=2.718^(-2)
    A=p
    U=rand(Uniform(0,1))
    
    while true
        if U<A
            X=i
            break
        else
            p = (2*p)/(1+i) 
            A = A + p
            i = i + 1
        end
        
    end    
    push!(arr,i)    
        
    

end    
    
display(histogram([arr]))
